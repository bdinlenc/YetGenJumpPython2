# %% [markdown]
# # Problem 1
# Vehicle sınıfından miras alan bir Bus sınıfı oluşturun. Bus.seating_capacity()'nin kapasite bağımsız değişkenine varsayılan olarak 50 değerini verin.
#
# ```
# Output:
# > The seating capacity of a bus is 50 passengers
# ```

# %%
class Vehicle:
    pass

class Bus(Vehicle):
      def seating_capacity(self, capacity = 50):
           print(f"The seating capacity of a bus is 50 passengers.")

my_bus = Bus()
my_bus.seating_capacity()

# %% [markdown]
# # Problem 2
#
#
# School_bus'ın aynı zamanda Vehicle sınıfının bir örneği olup olmadığını belirleyiniz.

# %%
class School_bus(Bus):
    pass

print(issubclass(School_bus, Vehicle))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 class School_bus(Bus):
#       2     pass
#       4 print(issubclass(School_bus, Vehicle))
#
# NameError: name 'Bus' is not defined
